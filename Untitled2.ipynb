# %% [markdown]
# <a href="https://colab.research.google.com/github/MouksineSanni/my-first-repo/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#The IF statement: A cell's Threshold
body_temperature = 38.5
if body_temperature > 37.5:
  print("Fever detected")
  print("Initiating immune response..")
  print(body_temperature)
# Out:
# Fever detected
# Initiating immune response..
# 38.5

# %%
if body_temperature > 37.5:
  print("Fever detected")
  print("Initiating immune response")
  print(body_temperature)
# Out:
# Fever detected
# Initiating immune response
# 38.5

# %%
ph_level = 6.8  # pH of a sample
if ph_level <  7.0:
  print("Solution is ACIDIC")
  print(f"pH: [ph_level]-below neutral")
else:
  print("Solution is NEUTRAL or ALKALINE")
  print(f"pH: [ph_level]-at or above neutral")
  print(ph_level)
# Out:
# Solution is ACIDIC
# pH: [ph_level]-below neutral

# %%
#Classifying a DNA sequence by GC Content
gc_content = 0.68  #68%
if gc_content < 0.40:
  classification = "AT-rich (low GC)"
  stability = "relatively unstable"
elif gc_content < 0.50:
    classification = "Moderate GC"
    stability = "moderate stability"
elif gc_content < 0.65:
    classification = "GC-rich"
    stability = "thermally stable"
else:
    classification = "Extremely GC-rich"
    stability = "very high therminal stability"
    print(f"Classification: [classification]")
    print(f"Thermal stability: [stability]")
    print(gc_content)
    gc_content = 0.35
    print(gc_content)
# Out:
# Classification: [classification]
# Thermal stability: [stability]
# 0.68
# 0.35

# %%
#A sample organism classifier
organism_name = "Streptococus pyogenes"
gram_positive = True
oxygen_requirement = "facultative anaerobe"
print(f"Classifying: [organism_name]")
if gram_positive:
  print("Gram-positive organism")
  # Now check oxygen requirements
if oxygen_requirement == "obligate aerobe":
    print("Category: Gram+ aerobe")
elif oxygen_requirement == "facultive anaerobe":
      print("Category: Gram+ facultative anaerobe")
else:
  print("Category: Gram+ anaerobe")

else:

print("Gram-negative organism")
print("Further classification requires additional tests")
print(organism_name)
# Out:
#   File "/tmp/ipykernel_226/2657820494.py", line 16
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
organism="staph A"
no_of_colonies=350
ph=7.5
status_live=alive

# %%
seq="ATCGGCTATGCCA"
print(len(seq))
my_name="mouksinesani"
print(len(my_name))
print(my_name[4])
print(seq[0:3])
print(seq[3:-1])
lower_seq= seq.lower()
print(lower_seq)
DELL_lower= "uagugguga"
upper_seq = DELL_lower.upper()
print(upper_seq)
# Out:
# 13
# 12
# s
# ATC
# GGCTATGCC
# atcggctatgcca
# UAGUGGUGA

# %%
#Concatenation means joining strings together with +
exon1="ATCGGC"
exon2="TATGCC"
exon3="AAGCTA"
mrna=exon1+exon2+exon3
print(mrna)
# Out:
# ATCGGCTATGCCAAGCTA

# %%
#Day1-Exercise
#Exercise1
organism_name ="S.cervisae"
body_mass=5,6
status_live = "endangered"
UFC_numb=50
report=f"Organism:[organism_name]. Weight:[body_mass].Status:[status_live].Colony:[UFC_numb]"
print(report)
# Out:
# Organism:[organism_name]. Weight:[body_mass]ng.Status:[status_live].Colony:[UFC_numb]

# %%
#Exercise2
DNA_seq="GCATCGATCGATCGCGATCG"
print(len(DNA_seq))
print(DNA_seq[0:7])
print(DNA_seq[-5:-1])
# Out:
# 20
# GCATCGA
# GATC

# %%
#Exercice3

# %%
#Loop: The rythm of biologicalRepetition
sequence = "ATCGGC"

# %%
#the basic of if statement
body_temperature = 36.5 #body fever is worse
if body_temperature >37.7:
   print("Fever detected")
   print("initiating immun response")

# %%
ph_level= 6.8 #ph of sample
if ph_level < 7.8:

   print("solution is acidic")
else:

    print("solution is neutral of alkalin")
# Out:
# solution is acidic
